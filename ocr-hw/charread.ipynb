# %%
from pylab import *image = mean(imread("c.png"),axis=2)gray()imshow(image)

# %%
rows = array(linspace(0,image.shape[0],31),'i')cols = array(linspace(0,image.shape[1],27),'i')chars = [[] for i in range(26)]for i in range(26):    for j in range(30):        chars[i].append(image[rows[j]:rows[j+1],cols[i]:cols[i+1]])

# %%
imshow(chars[15][0])print amin(chars[15][0]),amax(chars[15][0])
# Out:
# 0.302941 1.0

# %%
imshow(chars[15][0]<0.6)

# %%
from scipy.ndimage import measurements,filtersdef crop(c,threshold=0.6,r=5):    b = filters.maximum_filter(c<threshold,r)    sl = measurements.find_objects(b)[0]    return c[sl]imshow(crop(chars[15][0]))

# %%
chars = [[crop(c) for c in l] for l in chars]

# %%
def rescale(c):    return (c-amin(c))/(amax(c)-amin(c))

# %%
chars = [[1-rescale(c) for c in l] for l in chars]

# %%
out = zeros((32,32))for c in chars[15]: out[:c.shape[0],:c.shape[1]] += cimshow(out)

# %%
image = mean(imread("w.png"),axis=2)

# %%
image = rescale(amax(image)-image)

# %%
def standardize(image,b=None):    if b is None:        image -= mean(image)        image /= sum(image**2)        return image    bw,bh = b    image = image-filters.uniform_filter(image,b)    image /= sqrt(filters.uniform_filter(image**2,b))    return images = standardize(image,(30,30))imshow(s[:400,:400])

# %%
match = filters.convolve(s,chars[0][0][::-1,::-1])

# %%
imshow(match[:200,:200])
